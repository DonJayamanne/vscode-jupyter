# %% [markdown]
# #

# %% [markdown]
# ## Interactive window execution

# %%
#Some assertion failure
# Out:
# AssertionError: expected 1 to equal 3
#
# 	at Context.eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:160057:23)
# 	at callFn (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77967:22)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79732:13)
# 	at next (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79509:15)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79519:8)
# 	at next (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79394:15)
# 	at cbHookRun (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79463:8)
# 	at done (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77911:6)
# ...

# %%
#Some random failure
# Out:
# Error: kaboom
#
# 	at Context.eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:160060:15)
# 	at callFn (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77967:22)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79732:13)
# 	at next (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79509:15)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79519:8)
# 	at next (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79394:15)
# 	at cbHookRun (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79463:8)
# 	at done (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77911:6)
# ...

# %%
#Execute cell from input box
# Out:
# Error: Timeout of 120000ms exceeded. For async tests and hooks, ensure "done()" is called; if returning a Promise, ensure it resolves.
#
# 	at createTimeoutError$1 (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77522:14)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77842:25)
# 15:55:05.755: Start Test Execute cell from input box []
# 15:55:05.755: Setting Jupyter Server URI to remote: http://localhost:50865/?token%3De208c40c6f9a47458939b5ee645b54f3 []
# 15:55:05.756: Creating server with url : http://localhost:50865/ []
# 15:55:05.757: Disposing session manager []
# 15:55:05.758: SessionManager - dispose contents manager []
# 15:55:05.758: ShutdownSessionAndConnection - dispose session manager []
# 15:55:05.758: DataScience Error [ { [Error: Failed to connect to the remote Jupyter Server 'http://localhost:50865/'. Verify the server is running and reachable. (Failed to fetch).]
# ...

# %% [markdown]
# ## DataScience - VSCode Notebook - Standard

# %%
#Custom error
# Out:
# Error: kaboom
#
# 	at Context.eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:161358:15)
# 	at callFn (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77967:22)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79732:13)
# 	at next (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79509:15)
# 	at eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79519:8)
# 	at next (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79394:15)
# 	at cbHookRun (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:79463:8)
# 	at done (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:77911:6)
# ...

# %%
#Can run a widget notebook (webview-test)
# Out:
# AssertionError: No notebook controller found for python when useRemote is true and preferred kind is startUsingRemoteKernelSpec. NotebookControllers count: 0
#
# 	at waitForKernelToGetAutoSelected (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:160843:23)
# 	at async Context.eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:161369:9)
# 15:57:05.847: Opening notebook /214a0726-0193-4477-9776-b8765504bee7..ipynb []
# 15:57:05.851: Clear controller mapping for /214a0726-0193-4477-9776-b8765504bee7..ipynb []
# 15:57:05.851: CreateDefaultRemoteController []
# 15:57:05.851: No remote controllers []
# 15:57:05.851: Preferred Remote kernel for /214a0726-0193-4477-9776-b8765504bee7..ipynb is undefined []
# 15:57:05.880: No controller, hence notebook communications cannot be initialized for editor /214a0726-0193-4477-9776-b8765504bee7..ipynb []
# ...

# %%
#Can run a widget notebook twice (webview-test)
# Out:
# AssertionError: No notebook controller found for python when useRemote is true and preferred kind is startUsingRemoteKernelSpec. NotebookControllers count: 0
#
# 	at waitForKernelToGetAutoSelected (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:160843:23)
# 	at async Context.eval (http://localhost:3000/static/devextensions/out/extension.web.bundle.js#vscode-extension:161380:9)
# 15:57:37.530: Opening notebook /2596971e-0a38-44e0-9f6c-d7838d389d37..ipynb []
# 15:57:37.531: Clear controller mapping for /2596971e-0a38-44e0-9f6c-d7838d389d37..ipynb []
# 15:57:37.531: CreateDefaultRemoteController []
# 15:57:37.532: No remote controllers []
# 15:57:37.532: Preferred Remote kernel for /2596971e-0a38-44e0-9f6c-d7838d389d37..ipynb is undefined []
# 15:57:37.554: No controller, hence notebook communications cannot be initialized for editor /2596971e-0a38-44e0-9f6c-d7838d389d37..ipynb []
# ...
